# %% [markdown]
# Exercice from the book "Practical Machine Learning and Image Processing" (Himanshu Singh)

# %%
from keras.datasets import mnist
import keras

def load_and_preprocess():
    r, c = 28, 28
    num_classes = 10
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.reshape(x_train.shape[0], r, c, 1)
    x_test = x_test.reshape(x_test.shape[0], r, c, 1)

    input_shape = (r, c, 1)
    
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    
    x_train /= 255
    x_test /= 255
    
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    
    return (x_train,x_test,y_train,y_test,input_shape)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

x_train, x_test, y_train, y_test, input_shape = load_and_preprocess()
num_classes=10

model = Sequential()

#Now defining 2 convolution layers
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Next, we minimize errors by using the AdaDelta algorithm:
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta(), metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=10, epochs=10, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/10
# 6000/6000 [==============================] - 121s 20ms/step - loss: 2.1819 - accuracy: 0.3150 - val_loss: 1.9605 - val_accuracy: 0.6764
# Epoch 2/10
# 6000/6000 [==============================] - 121s 20ms/step - loss: 1.6783 - accuracy: 0.5905 - val_loss: 1.2186 - val_accuracy: 0.7974
# Epoch 3/10
# 6000/6000 [==============================] - 121s 20ms/step - loss: 1.1285 - accuracy: 0.6861 - val_loss: 0.7462 - val_accuracy: 0.8410
# Epoch 4/10
#  154/6000 [..............................] - ETA: 1:50 - loss: 0.9292 - accuracy: 0.7325
